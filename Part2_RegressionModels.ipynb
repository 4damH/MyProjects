# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# This is the second part of the report where two regression models will be used:
#
# * The Linear Regression Model
# * The Deep Neural Network Regression Model
#
# The above models will be trained and tested with the data prepared in the first part of the report. The aims of the second part of the report is to evaluate the conclusions from the first part using the linear regression model and DNN regression model.

# %% [markdown]
# # **METHODOLOGY**

# %% [markdown]
# For the purposes of this report the following components have been used for linear and DNN regression models:
#
# * [Python](https://www.python.org/) programming language
# * [pandas](https://pandas.pydata.org/) software for analysis and data manipulation in Python
# * [NumPy](https://numpy.org/) library for the Python - for advanced mathematical functions on large multi-dimensional arrays and matrices
# * [TensorFlow](https://www.tensorflow.org/) - free and open-source software library for machine learning
#
#
# The following statistical techniques have been used:
#
# * [Linear regression](https://www.oxfordreference.com/view/10.1093/acref/9780199541454.001.0001/acref-9780199541454-e-932) - the assumption that there is a linear relationship between variables x and y
# * [Root Mean Square Errors (RMSE)](https://www.researchgate.net/publication/262980567_Root_mean_square_error_RMSE_or_mean_absolute_error_MAE) as a performance measure. It is used to verify experimental results - shows how much error the model makes in its predictions.

# %% [markdown]
# # **RESULTS**

# %% [markdown]
# ## **I. LINEAR REGRESSION MODEL**

# %% [markdown]
# In this section the data frame will be created with the data prepared for linear regression model - saved as csv file on GitHub as **data_for_linear_regression_full.csv** in the part 1 of this report.

# %%
# create the data frame using pandas
import pandas as pd

# create data frame from csv file hosted on our github for linear regression
df = pd.read_csv('https://raw.githubusercontent.com/20023160uhi/20023160_Data_Analytics/main/data_for_linear_regression_full.csv', index_col=0, )

# %% [markdown]
# It is worth to see how the data looks like:

# %%
# print the data
print(df)
# Out:
#       day  temp  dewp  NUM_COLLISIONS
# 1       3  27.5  12.1       -1.077771
# 2       4  21.8   7.8       -0.162511
# 3       5  32.2  21.1       -0.746155
# 4       1  35.9  31.0       -0.533921
# 5       2  39.8  34.1       -0.640038
# ...   ...   ...   ...             ...
# 1749    2  42.8  33.7       -0.668066
# 1750    4  35.9  30.3       -2.084936
# 1751    5  40.1  35.0       -1.669647
# 1752    1  39.6  36.3       -0.814638
# 1753    2  44.7  42.6       -1.730719
#
# [1753 rows x 4 columns]

# %% [markdown]
# In the next step the data will be shuffled randomly by rows. Then the data from chosen columns will be determined as predictors for linear regression model. In this case the predictors are:
#
# * day - day of the week
# * temp - temperature
# * dewp - dew point
#
# Worth to notice is that has been decided in part 1 of the report, that for this model only weekdays are taking into account - without Saturdays and Sundays.

# %%
# import numpy package to help with speedy maths based calculations
import numpy as np

# use iloc to select by rows
# Shuffle the data by rows determined at random
shuffle = df.iloc[np.random.permutation(len(df))]

# select all rows of the columns outlined i.e. The 3rd (2 as indexes start from 0)
predictors = shuffle.iloc[:,0:3]

# print out the first 6 rows of predictors.
print(predictors[:6])
# Out:
#       day  temp  dewp
# 1154    5  67.7  66.7
# 83      3  49.9  41.4
# 750     2  58.0  51.5
# 747     4  51.1  46.4
# 456     4  65.0  63.4
# 1079    5  47.8  42.6

# %% [markdown]
# The first 6 rows of predictors have been shown above and below the first six lines for all the shuffled data (along with the number of collisions) can be seen.

# %%
# print out the shuffled data (first 6 rows)
shuffle[:6]
# Out:
#       day  temp  dewp  NUM_COLLISIONS
# 1154    5  67.7  66.7        1.539175
# 83      3  49.9  41.4        0.195635
# 750     2  58.0  51.5        1.776413
# 747     4  51.1  46.4        0.773438
# 456     4  65.0  63.4        0.420227
# 1079    5  47.8  42.6        0.805939

# %% [markdown]
# The next step is to specify the targets, which is the number of collisions. The first 6 lines of them are presented below.

# %%
# Select all rows for the 2nd column (i.e. 1)
targets = shuffle.iloc[:,3]

# print out the first 6 rows of the targets data.
print(targets[:6])
# Out:
# 1154    1.539175
# 83      0.195635
# 750     1.776413
# 747     0.773438
# 456     0.420227
# 1079    0.805939
# Name: NUM_COLLISIONS, dtype: float64

# %%
# define scale targets 
SCALE_NUM_COLLISIONS = 1.0

# %% [markdown]
# The dataset prepared for this model will be divided into two parts: 80 percent of the data will be used for training the model, and the remaining 20 percent for testing.

# %%
# Split the data into a training set: 80% of the length of the shuffle array
trainsize = int(len(shuffle['NUM_COLLISIONS'])*0.8)
# The test set size is 20% of the length of the shuffle array.
testsize = len(shuffle['NUM_COLLISIONS']) - trainsize

# Define the number of input values (predictors)
nppredictors = 3
# Define the number of output values (targets)
noutputs = 1

# %%
# see predictors
print(predictors)
# Out:
#       day  temp  dewp
# 1154    5  67.7  66.7
# 83      3  49.9  41.4
# 750     2  58.0  51.5
# 747     4  51.1  46.4
# 456     4  65.0  63.4
# ...   ...   ...   ...
# 455     3  64.9  62.1
# 1268    2  45.3  45.3
# 52      2  39.6  35.5
# 1092    3  53.1  51.8
# 746     3  43.7  32.9
#
# [1753 rows x 3 columns]

# %%
# see values of predictors
print(predictors.values)
# Out:
# [[ 5.  67.7 66.7]
#  [ 3.  49.9 41.4]
#  [ 2.  58.  51.5]
#  ...
#  [ 2.  39.6 35.5]
#  [ 3.  53.1 51.8]
#  [ 3.  43.7 32.9]]

# %%
# see values of targets
print(targets[:trainsize].values.reshape(trainsize, noutputs))
# Out:
# [[ 1.53917472]
#  [ 0.19563478]
#  [ 1.77641276]
#  ...
#  [-0.23379967]
#  [ 0.59560338]
#  [ 0.0586751 ]]

# %% [markdown]
# ### **Training the linear regression model**

# %%
# import tensorflow
# %tensorflow_version 1.x
import tensorflow as tf

# check the version
print(tf.__version__)

# import shutil module for high-level file management
import shutil  

# logging for tensorflow
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)

# removes a saved model from the last training attempt.
shutil.rmtree('/tmp/linear_regression_trained_model', ignore_errors=True)

# This is the core of the linear regressor

# You can see that we save the model, use the the Adam optimization algorithm, which is an extension 
# to stochastic gradient descent that has recently seen broader adoption for deep learning applications 
# in computer vision and natural language processing and infer real valued columns from input which interprets 
# all inputs as dense, fixed-length float values.

# See the link for more information
# https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/contrib/learn/LinearRegressor
estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir='/tmp/linear_regression_trained_model', optimizer=tf.train.AdamOptimizer(learning_rate=0.1), enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors.values)))

# Prints a log to show model is starting to train
print("starting to train");

# Train the model. Pass in predictor values and target values.
estimator.fit(predictors[:trainsize].values, targets[:trainsize].values.reshape(trainsize, noutputs)/SCALE_NUM_COLLISIONS, steps=10000)

# Next, we can check our predictions based on our predictors.
preds = estimator.predict(x=predictors[trainsize:].values)

# Apply the Scale value (not really needed here) to the outputs.
predslistscale = preds['scores']*SCALE_NUM_COLLISIONS

#pred = format(str(predslistscale)) # useful for checking outputs and printing.

# Calculate RMSE i.e. how good the model works using the predictions and targets.
# i.e. take the difference between the actual and the forecast then square the difference, 
# find the average of all the squares and then find the square root. 
# The RMSE essentially punishes larger errors i.e. it puts a heavier weight on larger errors.
rmse = np.sqrt(np.mean((targets[trainsize:].values - predslistscale)**2))
print('LinearRegression has RMSE of {0}'.format(rmse));


# Calculate the mean of the Number of vehicle collisions values.
avg = np.mean(shuffle['NUM_COLLISIONS'][:trainsize])

# Calculate the RMSE using Number of vehicle collisions values and the mean of all target values.
# The fit of a proposed regression model should therefore be better than the fit of the mean model.
# In this case, it doesn't seem to be the case but it will vary on every run.
rmse = np.sqrt(np.mean((shuffle['NUM_COLLISIONS'][trainsize:] - avg)**2))
print('Just using average = {0} has RMSE of {1}'.format(avg, rmse));
# Out:
# 1.15.2
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9f92aef050>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/linear_regression_trained_model', '_session_creation_timeout_secs': 7200}
# starting to train
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/linear_regression_trained_model/model.ckpt.
# INFO:tensorflow:loss = 0.7808527, step = 1
# INFO:tensorflow:global_step/sec: 861.312
# INFO:tensorflow:loss = 0.8490041, step = 101 (0.119 sec)
# INFO:tensorflow:global_step/sec: 1036.69
# INFO:tensorflow:loss = 0.6286543, step = 201 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1023.08
# INFO:tensorflow:loss = 0.8467711, step = 301 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1038.36
# INFO:tensorflow:loss = 0.65459657, step = 401 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1022.18
# INFO:tensorflow:loss = 0.6772189, step = 501 (0.101 sec)
# INFO:tensorflow:global_step/sec: 974.882
# INFO:tensorflow:loss = 0.7677897, step = 601 (0.099 sec)
# INFO:tensorflow:global_step/sec: 980.47
# INFO:tensorflow:loss = 0.7921282, step = 701 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1053.31
# INFO:tensorflow:loss = 1.0361629, step = 801 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1022.99
# INFO:tensorflow:loss = 0.6598369, step = 901 (0.100 sec)
# INFO:tensorflow:global_step/sec: 1046.69
# INFO:tensorflow:loss = 0.78683513, step = 1001 (0.096 sec)
# INFO:tensorflow:global_step/sec: 994.111
# INFO:tensorflow:loss = 0.74424696, step = 1101 (0.100 sec)
# INFO:tensorflow:global_step/sec: 1057.57
# INFO:tensorflow:loss = 0.93941486, step = 1201 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1050.95
# INFO:tensorflow:loss = 0.74162304, step = 1301 (0.094 sec)
# INFO:tensorflow:global_step/sec: 999.794
# INFO:tensorflow:loss = 1.1750021, step = 1401 (0.101 sec)
# INFO:tensorflow:global_step/sec: 1024.74
# INFO:tensorflow:loss = 0.72059137, step = 1501 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1001.59
# INFO:tensorflow:loss = 0.6507882, step = 1601 (0.100 sec)
# INFO:tensorflow:global_step/sec: 984.602
# INFO:tensorflow:loss = 0.80748785, step = 1701 (0.104 sec)
# INFO:tensorflow:global_step/sec: 917.618
# INFO:tensorflow:loss = 0.5799897, step = 1801 (0.108 sec)
# INFO:tensorflow:global_step/sec: 1008.8
# INFO:tensorflow:loss = 0.6337895, step = 1901 (0.097 sec)
# INFO:tensorflow:global_step/sec: 976.082
# INFO:tensorflow:loss = 0.66176224, step = 2001 (0.103 sec)
# INFO:tensorflow:global_step/sec: 1049.5
# INFO:tensorflow:loss = 1.0890684, step = 2101 (0.096 sec)
# INFO:tensorflow:global_step/sec: 980.55
# INFO:tensorflow:loss = 0.65625453, step = 2201 (0.101 sec)
# INFO:tensorflow:global_step/sec: 1079.99
# INFO:tensorflow:loss = 0.6276485, step = 2301 (0.095 sec)
# INFO:tensorflow:global_step/sec: 954.75
# INFO:tensorflow:loss = 0.88720715, step = 2401 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1053.88
# INFO:tensorflow:loss = 0.85082406, step = 2501 (0.098 sec)
# INFO:tensorflow:global_step/sec: 849.896
# INFO:tensorflow:loss = 0.8590392, step = 2601 (0.116 sec)
# INFO:tensorflow:global_step/sec: 1003.75
# INFO:tensorflow:loss = 0.7652153, step = 2701 (0.101 sec)
# INFO:tensorflow:global_step/sec: 996.565
# INFO:tensorflow:loss = 0.67456675, step = 2801 (0.103 sec)
# INFO:tensorflow:global_step/sec: 937.752
# INFO:tensorflow:loss = 1.267945, step = 2901 (0.102 sec)
# INFO:tensorflow:global_step/sec: 945.607
# INFO:tensorflow:loss = 1.186929, step = 3001 (0.107 sec)
# INFO:tensorflow:global_step/sec: 1014.07
# INFO:tensorflow:loss = 0.7114621, step = 3101 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1051.26
# INFO:tensorflow:loss = 0.7911905, step = 3201 (0.098 sec)
# INFO:tensorflow:global_step/sec: 952.852
# INFO:tensorflow:loss = 0.83801854, step = 3301 (0.105 sec)
# INFO:tensorflow:global_step/sec: 994.693
# INFO:tensorflow:loss = 0.7753842, step = 3401 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1000.92
# INFO:tensorflow:loss = 0.7973944, step = 3501 (0.101 sec)
# INFO:tensorflow:global_step/sec: 1011.92
# INFO:tensorflow:loss = 0.7865538, step = 3601 (0.101 sec)
# INFO:tensorflow:global_step/sec: 934.539
# INFO:tensorflow:loss = 0.87940353, step = 3701 (0.106 sec)
# INFO:tensorflow:global_step/sec: 1034.46
# INFO:tensorflow:loss = 1.4224782, step = 3801 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1004.45
# INFO:tensorflow:loss = 1.5415405, step = 3901 (0.104 sec)
# INFO:tensorflow:global_step/sec: 1020.82
# INFO:tensorflow:loss = 0.92647976, step = 4001 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1053.31
# INFO:tensorflow:loss = 1.4034036, step = 4101 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1027.77
# INFO:tensorflow:loss = 1.7846744, step = 4201 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1048.22
# INFO:tensorflow:loss = 0.7906906, step = 4301 (0.096 sec)
# INFO:tensorflow:global_step/sec: 1003.09
# INFO:tensorflow:loss = 1.1591345, step = 4401 (0.099 sec)
# INFO:tensorflow:global_step/sec: 1057.3
# INFO:tensorflow:loss = 1.3746548, step = 4501 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1007.24
# INFO:tensorflow:loss = 0.7425177, step = 4601 (0.101 sec)
# INFO:tensorflow:global_step/sec: 989.463
# INFO:tensorflow:loss = 0.9117307, step = 4701 (0.101 sec)
# INFO:tensorflow:global_step/sec: 988.146
# INFO:tensorflow:loss = 0.74679995, step = 4801 (0.102 sec)
# INFO:tensorflow:global_step/sec: 973.931
# INFO:tensorflow:loss = 1.2670387, step = 4901 (0.099 sec)
# INFO:tensorflow:global_step/sec: 1053.55
# INFO:tensorflow:loss = 0.9110644, step = 5001 (0.098 sec)
# INFO:tensorflow:global_step/sec: 969.028
# INFO:tensorflow:loss = 1.0450616, step = 5101 (0.103 sec)
# INFO:tensorflow:global_step/sec: 1050.31
# INFO:tensorflow:loss = 0.6641799, step = 5201 (0.093 sec)
# INFO:tensorflow:global_step/sec: 992.89
# INFO:tensorflow:loss = 0.77792853, step = 5301 (0.101 sec)
# INFO:tensorflow:global_step/sec: 999.76
# INFO:tensorflow:loss = 0.8666641, step = 5401 (0.103 sec)
# INFO:tensorflow:global_step/sec: 994.755
# INFO:tensorflow:loss = 0.80827844, step = 5501 (0.101 sec)
# INFO:tensorflow:global_step/sec: 984.324
# INFO:tensorflow:loss = 0.6737967, step = 5601 (0.097 sec)
# INFO:tensorflow:global_step/sec: 973.364
# INFO:tensorflow:loss = 0.7918114, step = 5701 (0.106 sec)
# INFO:tensorflow:global_step/sec: 1034.61
# INFO:tensorflow:loss = 0.7346202, step = 5801 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1010.23
# INFO:tensorflow:loss = 1.0634706, step = 5901 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1070.77
# INFO:tensorflow:loss = 0.8390064, step = 6001 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1006.27
# INFO:tensorflow:loss = 0.9590962, step = 6101 (0.099 sec)
# INFO:tensorflow:global_step/sec: 908.464
# INFO:tensorflow:loss = 1.2220423, step = 6201 (0.110 sec)
# INFO:tensorflow:global_step/sec: 929.729
# INFO:tensorflow:loss = 0.7978607, step = 6301 (0.108 sec)
# INFO:tensorflow:global_step/sec: 1061.22
# INFO:tensorflow:loss = 0.7602838, step = 6401 (0.097 sec)
# INFO:tensorflow:global_step/sec: 1024.95
# INFO:tensorflow:loss = 0.7328991, step = 6501 (0.094 sec)
# INFO:tensorflow:global_step/sec: 1035.88
# INFO:tensorflow:loss = 1.270532, step = 6601 (0.097 sec)
# INFO:tensorflow:global_step/sec: 952.781
# INFO:tensorflow:loss = 0.9907197, step = 6701 (0.107 sec)
# INFO:tensorflow:global_step/sec: 1029.09
# INFO:tensorflow:loss = 0.62595034, step = 6801 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1005.73
# INFO:tensorflow:loss = 0.69761944, step = 6901 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1024.5
# INFO:tensorflow:loss = 1.5245916, step = 7001 (0.095 sec)
# INFO:tensorflow:global_step/sec: 991.149
# INFO:tensorflow:loss = 0.8554151, step = 7101 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1039.87
# INFO:tensorflow:loss = 0.83023167, step = 7201 (0.098 sec)
# INFO:tensorflow:global_step/sec: 871.386
# INFO:tensorflow:loss = 0.7163968, step = 7301 (0.112 sec)
# INFO:tensorflow:global_step/sec: 978.948
# INFO:tensorflow:loss = 0.83051324, step = 7401 (0.102 sec)
# INFO:tensorflow:global_step/sec: 989.244
# INFO:tensorflow:loss = 0.70908535, step = 7501 (0.104 sec)
# INFO:tensorflow:global_step/sec: 960.015
# INFO:tensorflow:loss = 0.7113273, step = 7601 (0.102 sec)
# INFO:tensorflow:global_step/sec: 940.149
# INFO:tensorflow:loss = 1.1014132, step = 7701 (0.108 sec)
# INFO:tensorflow:global_step/sec: 1013.39
# INFO:tensorflow:loss = 0.6674239, step = 7801 (0.099 sec)
# INFO:tensorflow:global_step/sec: 876.947
# INFO:tensorflow:loss = 0.92405343, step = 7901 (0.114 sec)
# INFO:tensorflow:global_step/sec: 992.88
# INFO:tensorflow:loss = 0.62645614, step = 8001 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1026.4
# INFO:tensorflow:loss = 0.71445185, step = 8101 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1059.53
# INFO:tensorflow:loss = 0.7737008, step = 8201 (0.097 sec)
# INFO:tensorflow:global_step/sec: 995.985
# INFO:tensorflow:loss = 0.7101158, step = 8301 (0.098 sec)
# INFO:tensorflow:global_step/sec: 1060.68
# INFO:tensorflow:loss = 0.84418136, step = 8401 (0.093 sec)
# INFO:tensorflow:global_step/sec: 1055.13
# INFO:tensorflow:loss = 0.75687087, step = 8501 (0.096 sec)
# INFO:tensorflow:global_step/sec: 962.182
# INFO:tensorflow:loss = 1.2260001, step = 8601 (0.103 sec)
# INFO:tensorflow:global_step/sec: 999.57
# INFO:tensorflow:loss = 1.0024686, step = 8701 (0.101 sec)
# INFO:tensorflow:global_step/sec: 1001.63
# INFO:tensorflow:loss = 0.8777591, step = 8801 (0.100 sec)
# INFO:tensorflow:global_step/sec: 964.033
# INFO:tensorflow:loss = 0.59148955, step = 8901 (0.105 sec)
# INFO:tensorflow:global_step/sec: 965.422
# INFO:tensorflow:loss = 0.89279425, step = 9001 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1052.57
# INFO:tensorflow:loss = 1.8041049, step = 9101 (0.095 sec)
# INFO:tensorflow:global_step/sec: 968.409
# INFO:tensorflow:loss = 0.8221692, step = 9201 (0.102 sec)
# INFO:tensorflow:global_step/sec: 1056.65
# INFO:tensorflow:loss = 1.2858636, step = 9301 (0.095 sec)
# INFO:tensorflow:global_step/sec: 1030.03
# INFO:tensorflow:loss = 0.9200274, step = 9401 (0.100 sec)
# INFO:tensorflow:global_step/sec: 1018.08
# INFO:tensorflow:loss = 0.8532611, step = 9501 (0.096 sec)
# INFO:tensorflow:global_step/sec: 996.43
# INFO:tensorflow:loss = 0.67719984, step = 9601 (0.100 sec)
# INFO:tensorflow:global_step/sec: 994.576
# INFO:tensorflow:loss = 1.5697014, step = 9701 (0.101 sec)
# INFO:tensorflow:global_step/sec: 1071.37
# INFO:tensorflow:loss = 0.9005567, step = 9801 (0.093 sec)
# INFO:tensorflow:global_step/sec: 988.866
# INFO:tensorflow:loss = 0.9315088, step = 9901 (0.101 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/linear_regression_trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.786247.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/linear_regression_trained_model/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# LinearRegression has RMSE of 0.8986772152123146
# Just using average = 0.349233942180536 has RMSE of 0.906158995855328

# %% [markdown]
# This model has been launched four times. It was only the fourth time that the RDMS value was relatively low.
#
# Each run gave the following values:
#
# * First attempt: `LinearRegression has RMSE of 0.9154298743550359. Just using average = 0.3449799013019476 has RMSE of 0.9152411831919334`
# * Second attempt: `LinearRegression has RMSE of 0.9467731581299792. Just using average = 0.34797110838693696 has RMSE of 0.9221486842188588`
# * Third attempt: `LinearRegression has RMSE of 1.0418983215461957. Just using average = 0.3092714154978759 has RMSE of 0.8745654169987936`
# * Fourth attempt: `LinearRegression has RMSE of 0.8986772152123146. Just using average = 0.349233942180536 has RMSE of 0.906158995855328`

# %% [markdown]
# ### **Testing the linear regression model**

# %% [markdown]
# The data displayed below will be used as reference to values using for tests. It is worth checking whether by examining the increase in the value of only one factor out of three, our model will show the expected increase in the value of the number of collisions.

# %%
# print the predictors for test
print(predictors[:testsize])
# Out:
#       day  temp  dewp
# 1154    5  67.7  66.7
# 83      3  49.9  41.4
# 750     2  58.0  51.5
# 747     4  51.1  46.4
# 456     4  65.0  63.4
# ...   ...   ...   ...
# 1006    4  38.9  32.3
# 88      3  59.4  54.7
# 1178    4  67.1  65.1
# 165     5  70.6  65.0
# 1656    2  71.2  68.7
#
# [351 rows x 3 columns]

# %%
# see row 1656   ###AH: REMOVE IT!!!###
print(df.loc[[1656]])
# Out:
#       day  temp  dewp  NUM_COLLISIONS
# 1656    2  71.2  68.7       -1.413144

# %% [markdown]
# #### **1. Day of the week**

# %% [markdown]
# The day of the week will be the first factor that may affect the number of collisions. It is worth noting that for the purposes of this model, it was decided in the first part of the report that only days from Monday to Friday will be taken into account. The thesis presented earlier assumes that the number of collisions increases depending on the day of the week - for Monday it should be the smallest, and for Friday - the highest.

# %%
input = pd.DataFrame.from_dict(data = 
				{'day' : [3, 4, 5],
         'temp' : [38.9, 38.9, 38.9],
         'dewp' : [32.3, 32.3, 32.3]
        })
					

estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir='/tmp/linear_regression_trained_model', enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(input.values)))

preds = estimator.predict(x=input.values)
predslistnorm = preds['scores']
# predslistscale = preds['scores']*600000
prednorm = format(str(predslistnorm))
# pred = format(str(predslistscale))
print(prednorm)
# print(pred)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9f8300ab50>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/linear_regression_trained_model', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/linear_regression_trained_model/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [-0.14617062 -0.00893664  0.12829733]

# %% [markdown]
# The test was run three times:
#
# > For the first attempt, days 1, 3 and 5 were selected corresponding to Monday, Wednesday and Friday. The predicted values were estimated keeping the same temperature (value 60) and dew point (value 54.7) for all three days. The following results were obtained:
# * `-0.2299912` for day 1 (Monday)
# * `0.04447675` for day 2 (Wednesday)
# * `0.3189448` for day 5 (Friday)
#
# > For the second attempt, the values for days were  2, 3, 4. The values for temperature were 51.1, whereas for dew point 46.4. The following results were obtained:
# * `-0.19163096` for day 2 (Tueasday)
# * `-0.05439687` for day 3 (Wednesday)
# * `0.0828371` for day 4 (Thursday)
#
# > For the third attempt, the values for days were  3, 4, 5. The values for temperature were 38.9, whereas for dew point 32.3. The following results were obtained:
# * `-0.14617062` for day 3 (Wednesday)
# * `-0.00893664` for day 4 (Thursday)
# * `0.12829733` for day 5 (Friday)
#
# Based on the results it can be concluded that the model predicts an increase in the number of collisions from Monday to Friday. This confirms the conclusions drawn in the first part of the report.

# %% [markdown]
# #### **2. Temperature**

# %% [markdown]
# As before for the day of the week, now the influence of temperature on the number of traffic collisions will be examined, with the values for the rest of the predictors on the individual days unchanged.

# %%
input = pd.DataFrame.from_dict(data = 
				{'day' : [3, 3, 3],
         'temp' : [49.9, 59.4, 67.7],
         'dewp' : [41.4, 41.4, 41.4]
        })
					

estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir='/tmp/linear_regression_trained_model', enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(input.values)))

preds = estimator.predict(x=input.values)
predslistnorm = preds['scores']
# predslistscale = preds['scores']*600000
prednorm = format(str(predslistnorm))
# pred = format(str(predslistscale))
print(prednorm)
# print(pred)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9f82ff4590>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/linear_regression_trained_model', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/linear_regression_trained_model/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [-0.00534689  0.2426002   0.45922756]

# %% [markdown]
# Three tests were conducted:
# > For the first attempt, the values for days were 2, whereas for dew point were 54.7. The following results were obtained:
# * `-0.64346063` for the temperature value of 38.9
# * `-0.10841703` for the temperature value of 59.4
# * `0.18389952` for the temperature value of 70.6
#
# > For the second attempt, the values for days were 1, whereas for dew point were 51.5. The following results were obtained:
# * `-0.41084194` for the temperature value of 51.1
# * `-0.23075402` for the temperature value of 58.0
# * `-0.19421446` for the temperature value of 59.4
#
# > For the third attempt, the values for days were 3, whereas for dew point were 41.4. The following results were obtained:
# * `-0.00534689` for the temperature value of 49.9
# * `0.2426002` for the temperature value of 59.4
# * `0.45922756` for the temperature value of 67.7
#
# The conclusion presented in the first part of the report that the number of collisions increases when temperature increases is confirmed by the values predicted by the model.

# %% [markdown]
# #### **3. Dew point**

# %% [markdown]
# The last weather factor left to be tested is the dew point. As with the previous tests, the other predictors (in this case: day of the week and temperature) will have a constant value.

# %%
input = pd.DataFrame.from_dict(data = 
				{'day' : [4, 4, 4],
         'temp' : [51.1, 51.1, 51.1],
         'dewp' : [32.3, 46.4, 63.4]
        })
					

estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir='/tmp/linear_regression_trained_model', enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(input.values)))

preds = estimator.predict(x=input.values)
predslistnorm = preds['scores']
# predslistscale = preds['scores']*600000
prednorm = format(str(predslistnorm))
# pred = format(str(predslistscale))
print(prednorm)
# print(pred)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9f82f0fdd0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/linear_regression_trained_model', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/linear_regression_trained_model/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [ 0.30947948  0.0828371  -0.19041961]

# %% [markdown]
# Three attepts were carried out:
#
# > For the first attempt, the values for days were  1, whereas for temperature were 67.1. The following results were obtained:
# * `0.31537247` for the dew point value 32.3
# * `-0.04468346` for the dew point value 54.7
# * `-0.2102449` for the dew point value 65.0
#
# > For the second attempt, the values for days were  5, whereas for temperature were 67.7. The following results were obtained:
# * `0.38006926` for the dew point value 63.4
# * `0.3270253` for the dew point value 66.7
# * `0.2948774` for the dew point value 68.7
#
# > For the third attempt, the values for days were  4, whereas for temperature were 51.1. The following results were obtained:
# * `0.30947948` for the dew point value 32.3
# * `0.0828371` for the dew point value 46.4
# * `-0.19041961` for the dew point value 63.4
#
#
# Based on the results above, it cannot be concluded that a higher dew point results in a higher number of collisions. The given outputs indicate something completely opposite - as the value of the dew point increases, the predicted number of collisions decreases.

# %% [markdown]
# ---

# %% [markdown]
# ## **II. DNN REGRESSION MODEL**

# %% [markdown]
# The deep neural network regression model is a complex model used to detect patterns that are difficult to detect in the analysis performed in the first part of the report. The data prepared for this model includes all weather factors, days, months and years from 2013 to 2019 with the number of vehicle collisions per day.
# One hot encoding has been used to create matrix for months and days of the week.

# %%
# create the data frame using pandas
import pandas as pd

# create data frame from csv file hosted on github
df = pd.read_csv('https://raw.githubusercontent.com/20023160uhi/20023160_Data_Analytics/main/data_for_dnn_regression_full.csv', index_col=0)

# %%
# make sure we have our data by printing it out
print(df)
# Out:
#       Apr  Aug  Dec  Feb  Jan  Jul  ...   max   min  prcp  sndp  fog  NUM_COLLISIONS
# 1       0    0    0    0    1    0  ...  33.1  21.9  0.00   NaN    0             480
# 2       0    0    0    0    1    0  ...  28.9  16.0  0.00   NaN    0             549
# 3       0    0    0    0    1    0  ...  41.0  24.1  0.00   NaN    0             505
# 4       0    0    0    0    1    0  ...  42.1  28.0  0.01   NaN    0             521
# 5       0    0    0    0    1    0  ...  48.0  25.0  0.00   NaN    0             513
# ...   ...  ...  ...  ...  ...  ...  ...   ...   ...   ...   ...  ...             ...
# 2445    0    0    1    0    0    0  ...  50.0  34.0  0.00   NaN    0             530
# 2446    0    0    1    0    0    0  ...  46.4  28.9  0.00   NaN    0             414
# 2447    0    0    1    0    0    0  ...  48.0  28.9  0.00   NaN    0             448
# 2448    0    0    1    0    0    0  ...  45.0  30.9  0.39   NaN    0             518
# 2449    0    0    1    0    0    0  ...  52.0  37.9  0.88   NaN    1             443
#
# [2449 rows x 33 columns]

# %% [markdown]
# The data prepared for this model is visible above. The dataset contains 33 columns: 12 for months, 7 for days of the week, one for the year, another 12 for weather factors (temp, dewp, slp, visib, wdsp, mxpsd, taste, max, min, prcp, sndp, fog) and the last for the number of vehicle collisions (NUM_COLLISIONS).
#
# Next step is to shuffle the data and define predictors. For this model predictors are months, days, years and the weather factors (temp, dewp, slp, visib, wdsp, mxpsd, taste, max, min, prcp, sndp, fog).

# %%
# needed to help with speedy maths based calculations
import numpy as np

# iloc allows us to select by rows. Here, we are shuffling the data by rows determined at random.
shuffle = df.iloc[np.random.permutation(len(df))]

# we are selecting all rows of the columns outliined i.e. The 3rd (2 as indexes start from 0)
predictors = shuffle.iloc[:,0:32]
# Since it is the last column, we can also use
# predictorTest = shuffle.iloc[:,-1]

# print out the first 6 rows of predictors.
print(predictors[:6])
# Out:
#       Apr  Aug  Dec  Feb  Jan  Jul  ...  gust   max   min  prcp  sndp  fog
# 1093    0    0    0    1    0    0  ...  38.1  50.0  36.0  0.02   NaN    1
# 2261    0    0    0    0    0    0  ...   NaN  69.1  57.9  0.32   NaN    1
# 371     0    0    0    0    1    0  ...  24.1  28.9   9.0  0.00   NaN    0
# 1263    0    1    0    0    0    0  ...   NaN  82.0  66.9  0.00   NaN    1
# 531     0    0    0    0    0    1  ...  26.0  77.0  62.1  0.11   NaN    0
# 1460    0    0    0    1    0    0  ...   NaN  48.9  30.0  0.00   NaN    0
#
# [6 rows x 32 columns]

# %% [markdown]
# This is how the first 5 rows of shuffled data for predictors looks like:

# %%
# print out the shuffled data (first 5 rows)
shuffle[:5]
# Out:
#       Apr  Aug  Dec  Feb  Jan  Jul  ...   max   min  prcp  sndp  fog  NUM_COLLISIONS
# 1093    0    0    0    1    0    0  ...  50.0  36.0  0.02   NaN    1             615
# 2261    0    0    0    0    0    0  ...  69.1  57.9  0.32   NaN    1             591
# 371     0    0    0    0    1    0  ...  28.9   9.0  0.00   NaN    0             612
# 1263    0    1    0    0    0    0  ...  82.0  66.9  0.00   NaN    1             540
# 531     0    0    0    0    0    1  ...  77.0  62.1  0.11   NaN    0             451
#
# [5 rows x 33 columns]

# %% [markdown]
# Now the targets will be defined:

# %%
# Select all rows for the last column (NUM_COLLISIONS)
targets = shuffle.iloc[:,32]

# print out the first 6 rows of the targets data.
print(targets[:6])
# Out:
# 1093    615
# 2261    591
# 371     612
# 1263    540
# 531     451
# 1460    591
# Name: NUM_COLLISIONS, dtype: int64

# %% [markdown]
# The values of the targets have to be scaled. This will be done in the cell below.

# %%
# scale the values of targets
SCALE_NUM_COLLISIONS = 1.0

# %% [markdown]
# The next step is to split the data into two sets - one for model training (80%) and one for testing(20%). Then, the number of input values (predictors) will be defined as 32 and the number of output values (targets - NUM_COLLISIONS) will be set up as 1.

# %%
# Split our data into a training set i.e. 80% of the length of the shuffle array
trainsize = int(len(shuffle['NUM_COLLISIONS'])*0.8)
# The test set size is 100% - 80% = 20% of the length of the shuffle array.
testsize = len(shuffle['NUM_COLLISIONS']) - trainsize

# Define the number of input values (predictors)
nppredictors = 32
# Define the number of output values (targets)
noutputs = 1

# %% [markdown]
# > **Issues to run the DNN regression model**

# %%
# import tensorflow
# %tensorflow_version 1.x
import tensorflow as tf

# check the version
print(tf.__version__)

# needed for high-level file management
import shutil  

# logging for tensorflow
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)

# removes a saved model from the last training attempt.
shutil.rmtree('/tmp/DNN_house_regression_trained_model', ignore_errors=True)

estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.DNNRegressor(model_dir='/tmp/DNN_house_regression_trained_model', hidden_units=[20,18,14], optimizer=tf.train.AdamOptimizer(learning_rate=0.01), enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors.values)))

# Prints a log to show model is starting to train
print("starting to train");

# Train the model. Pass in predictor values and target values.
estimator.fit(predictors[:trainsize].values, targets[:trainsize].values.reshape(trainsize, noutputs)/SCALE_NUM_COLLISIONS, steps=10000)

# Next, we can check our predictions based on our predictors.
preds = estimator.predict(x=predictors[trainsize:].values)

# Apply the Scale value (not really needed here) to the outputs.
predslistscale = preds['scores']*SCALE_NUM_COLLISIONS

# pred = format(str(predslistscale)) # useful for checking outputs and printing.

# Calculate RMSE i.e. how good the model works using the predictions and targets.
# i.e. take the difference between the actual and the forecast then square the difference, 
# find the average of all the squares and then find the square root. 
# The RMSE essentially punishes larger errors i.e. it puts a heavier weight on larger errors.
rmse = np.sqrt(np.mean((targets[trainsize:].values - predslistscale)**2))
print('DNNRegression has RMSE of {0}'.format(rmse));


# Calculate the mean of the Number of Collisions Values.
avg = np.mean(shuffle['NUM_COLLISIONS'][:trainsize])

# Calculate the RMSE using the Number of Collisions Values and the mean of all target values.
# The fit of a proposed regression model should therefore be better than the fit of the mean model.
# In this case, it doesn't seem to be the case but it will vary on every run.
rmse = np.sqrt(np.mean((shuffle['NUM_COLLISIONS'][trainsize:] - avg)**2))
print('Just using average = {0} has RMSE of {1}'.format(avg, rmse));
# Out:
# 1.15.2
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa96bd47e50>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/DNN_house_regression_trained_model', '_session_creation_timeout_secs': 7200}
# starting to train
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/DNN_house_regression_trained_model/model.ckpt.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# InvalidArgumentError: Nan in summary histogram for: dnn/dnn/hiddenlayer_0_activation
# 	 [[{{node dnn/dnn/hiddenlayer_0_activation}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-26-e04b28134033> in <module>()
#      21
#      22 # Train the model. Pass in predictor values and target values.
# ---> 23 estimator.fit(predictors[:trainsize].values, targets[:trainsize].values.reshape(trainsize, noutputs)/SCALE_NUM_COLLISIONS, steps=10000)
#      24
#      25 # Next, we can check our predictions based on our predictors.
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, batch_size, steps, max_steps, monitors)
#    1525         steps=steps,
#    1526         max_steps=max_steps,
# -> 1527         monitors=all_monitors)
#    1528     return self
#    1529
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     522       hooks.append(basic_session_run_hooks.StopAtStepHook(steps, max_steps))
#     523
# --> 524     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     525     logging.info('Loss for final step: %s.', loss)
#     526     return self
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py in _train_model(self, input_fn, hooks)
#    1093         loss = None
#    1094         while not mon_sess.should_stop():
# -> 1095           _, loss = mon_sess.run([model_fn_ops.train_op, model_fn_ops.loss])
#    1096       return loss
#    1097
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1257             feed_dict=feed_dict,
#    1258             options=options,
# -> 1259             run_metadata=run_metadata)
#    1260       except _PREEMPTION_ERRORS as e:
#    1261         logging.info(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1358         raise six.reraise(*original_exc_info)
#    1359       else:
# -> 1360         raise six.reraise(*original_exc_info)
#    1361
#    1362
#
# /usr/local/lib/python3.7/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1343   def run(self, *args, **kwargs):
#    1344     try:
# -> 1345       return self._sess.run(*args, **kwargs)
#    1346     except _PREEMPTION_ERRORS:
#    1347       raise
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1416         feed_dict=feed_dict,
#    1417         options=options,
# -> 1418         run_metadata=run_metadata)
#    1419
#    1420     for hook in self._hooks:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1174
#    1175   def run(self, *args, **kwargs):
# -> 1176     return self._sess.run(*args, **kwargs)
#    1177
#    1178   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# InvalidArgumentError: Nan in summary histogram for: dnn/dnn/hiddenlayer_0_activation
# 	 [[node dnn/dnn/hiddenlayer_0_activation (defined at /tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py:1748) ]]
#
# Original stack trace for 'dnn/dnn/hiddenlayer_0_activation':
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 451, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 434, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-26-e04b28134033>", line 23, in <module>
#     estimator.fit(predictors[:trainsize].values, targets[:trainsize].values.reshape(trainsize, noutputs)/SCALE_NUM_COLLISIONS, steps=10000)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py", line 1527, in fit
#     monitors=all_monitors)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py", line 524, in fit
#     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py", line 1041, in _train_model
#     model_fn_ops = self._get_train_ops(features, labels)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py", line 1265, in _get_train_ops
#     return self._call_model_fn(features, labels, model_fn_lib.ModeKeys.TRAIN)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/estimator.py", line 1228, in _call_model_fn
#     model_fn_results = self._model_fn(features, labels, **kwargs)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/dnn.py", line 180, in _dnn_model_fn
#     _add_hidden_layer_summary(net, hidden_layer_scope.name)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/estimators/dnn.py", line 83, in _add_hidden_layer_summary
#     summary.histogram("%s_activation" % tag, value)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/summary/summary.py", line 179, in histogram
#     tag=tag, values=values, name=scope)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/gen_logging_ops.py", line 329, in histogram_summary
#     "HistogramSummary", tag=tag, values=values, name=name)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %% [markdown]
# The model could not run above. This might be caused by NaN values in the dataset. This will be investigated below.

# %% [markdown]
# > **Cleaning the data for DNN model**

# %%
# check missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2449 entries, 1 to 2449
# Data columns (total 33 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Apr             2449 non-null   int64
#  1   Aug             2449 non-null   int64
#  2   Dec             2449 non-null   int64
#  3   Feb             2449 non-null   int64
#  4   Jan             2449 non-null   int64
#  5   Jul             2449 non-null   int64
#  6   Jun             2449 non-null   int64
#  7   Mar             2449 non-null   int64
#  8   May             2449 non-null   int64
#  9   Nov             2449 non-null   int64
#  10  Oct             2449 non-null   int64
#  11  Sep             2449 non-null   int64
#  12  Fri             2449 non-null   int64
#  13  Mon             2449 non-null   int64
#  14  Sat             2449 non-null   int64
#  15  Sun             2449 non-null   int64
#  16  Thu             2449 non-null   int64
#  17  Tue             2449 non-null   int64
#  18  Wed             2449 non-null   int64
#  19  year            2449 non-null   int64
#  20  temp            2449 non-null   float64
#  21  dewp            2448 non-null   float64
#  22  slp             2448 non-null   float64
#  23  visib           2449 non-null   float64
#  24  wdsp            2449 non-null   float64
#  25  mxpsd           2446 non-null   float64
#  26  gust            1546 non-null   float64
#  27  max             2449 non-null   float64
#  28  min             2449 non-null   float64
#  29  prcp            2432 non-null   float64
#  30  sndp            0 non-null      float64
#  31  fog             2449 non-null   int64
#  32  NUM_COLLISIONS  2449 non-null   int64
# dtypes: float64(11), int64(22)
# memory usage: 650.5 KB

# %% [markdown]
# The significant number of missing values are in columns gust and sndp. These columns will be removed and from the rest columns rows which contain other NaN will be removed and saved as ***df_2*** dataset.

# %%
# remove columns with significant number of NaNs
df_2 = df.drop(['gust', 'sndp'], axis=1)

# %%
# remove other rows with NaNs from the rest of columns
df_2 = df_2.dropna(axis = 0)

# %%
# see if all NaNs have been removed
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2427 entries, 1 to 2449
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Apr             2427 non-null   int64
#  1   Aug             2427 non-null   int64
#  2   Dec             2427 non-null   int64
#  3   Feb             2427 non-null   int64
#  4   Jan             2427 non-null   int64
#  5   Jul             2427 non-null   int64
#  6   Jun             2427 non-null   int64
#  7   Mar             2427 non-null   int64
#  8   May             2427 non-null   int64
#  9   Nov             2427 non-null   int64
#  10  Oct             2427 non-null   int64
#  11  Sep             2427 non-null   int64
#  12  Fri             2427 non-null   int64
#  13  Mon             2427 non-null   int64
#  14  Sat             2427 non-null   int64
#  15  Sun             2427 non-null   int64
#  16  Thu             2427 non-null   int64
#  17  Tue             2427 non-null   int64
#  18  Wed             2427 non-null   int64
#  19  year            2427 non-null   int64
#  20  temp            2427 non-null   float64
#  21  dewp            2427 non-null   float64
#  22  slp             2427 non-null   float64
#  23  visib           2427 non-null   float64
#  24  wdsp            2427 non-null   float64
#  25  mxpsd           2427 non-null   float64
#  26  max             2427 non-null   float64
#  27  min             2427 non-null   float64
#  28  prcp            2427 non-null   float64
#  29  fog             2427 non-null   int64
#  30  NUM_COLLISIONS  2427 non-null   int64
# dtypes: float64(9), int64(22)
# memory usage: 606.8 KB

# %% [markdown]
# Now, when the data have been cleaned the procedure for DNN model has to be repeated:

# %% [markdown]
# > **Repeat steps for the DNN Regression Model with cleaned dataset *df_2***

# %%
# make sure we have our data by printing it out
print(df_2)
# Out:
#       Apr  Aug  Dec  Feb  Jan  ...   max   min  prcp  fog  NUM_COLLISIONS
# 1       0    0    0    0    1  ...  33.1  21.9  0.00    0             480
# 2       0    0    0    0    1  ...  28.9  16.0  0.00    0             549
# 3       0    0    0    0    1  ...  41.0  24.1  0.00    0             505
# 4       0    0    0    0    1  ...  42.1  28.0  0.01    0             521
# 5       0    0    0    0    1  ...  48.0  25.0  0.00    0             513
# ...   ...  ...  ...  ...  ...  ...   ...   ...   ...  ...             ...
# 2445    0    0    1    0    0  ...  50.0  34.0  0.00    0             530
# 2446    0    0    1    0    0  ...  46.4  28.9  0.00    0             414
# 2447    0    0    1    0    0  ...  48.0  28.9  0.00    0             448
# 2448    0    0    1    0    0  ...  45.0  30.9  0.39    0             518
# 2449    0    0    1    0    0  ...  52.0  37.9  0.88    1             443
#
# [2427 rows x 31 columns]

# %%
# needed to help with speedy maths based calculations
import numpy as np

# iloc allows us to select by rows. Here, we are shuffling the data by rows determined at random.
shuffle = df_2.iloc[np.random.permutation(len(df_2))]

# we are selecting all rows of the columns outliined i.e. The 3rd (2 as indexes start from 0)
predictors = shuffle.iloc[:,0:30]
# Since it is the last column, we can also use
# predictorTest = shuffle.iloc[:,-1]

# print out the first 6 rows of predictors.
print(predictors[:6])
# Out:
#       Apr  Aug  Dec  Feb  Jan  Jul  ...  wdsp  mxpsd   max   min  prcp  fog
# 1325    0    0    0    0    0    0  ...  24.8   36.9  57.0  51.8  3.76    0
# 1084    0    0    0    1    0    0  ...  17.9   31.1  54.0  32.0  1.44    1
# 303     0    0    0    0    0    0  ...  11.4   20.0  64.0  37.0  0.01    0
# 1724    0    0    1    0    0    0  ...  15.0   26.0  57.0  28.0  0.47    0
# 532     0    0    0    0    0    1  ...  13.9   15.9  73.9  63.0  0.04    0
# 1527    0    0    0    0    0    0  ...   6.2    8.9  55.0  39.9  0.00    0
#
# [6 rows x 30 columns]

# %%
# print out the shuffled data (first 5 rows)
shuffle[:5]
# Out:
#       Apr  Aug  Dec  Feb  Jan  ...   max   min  prcp  fog  NUM_COLLISIONS
# 1325    0    0    0    0    0  ...  57.0  51.8  3.76    0             539
# 1084    0    0    0    1    0  ...  54.0  32.0  1.44    1             607
# 303     0    0    0    0    0  ...  64.0  37.0  0.01    0             646
# 1724    0    0    1    0    0  ...  57.0  28.0  0.47    0             651
# 532     0    0    0    0    0  ...  73.9  63.0  0.04    0             614
#
# [5 rows x 31 columns]

# %%
# Select all rows for the last column (NUM_COLLISIONS)
targets = shuffle.iloc[:,30]

# print out the first 6 rows of the targets data.
print(targets[:6])
# Out:
# 1325    539
# 1084    607
# 303     646
# 1724    651
# 532     614
# 1527    651
# Name: NUM_COLLISIONS, dtype: int64

# %%
# scale the values of targets
SCALE_NUM_COLLISIONS = 1.0

# %% [markdown]
# This time the number of predictors is 30, because two weather factors have been removed (gust and sndp) during cleaning.

# %%
# Split our data into a training set i.e. 80% of the length of the shuffle array
trainsize = int(len(shuffle['NUM_COLLISIONS'])*0.8)
# The test set size is 100% - 80% = 20% of the length of the shuffle array.
testsize = len(shuffle['NUM_COLLISIONS']) - trainsize

# Define the number of input values (predictors)
nppredictors = 30
# Define the number of output values (targets)
noutputs = 1

# %% [markdown]
# ### **Training the DNN regression model**

# %%
# import tensorflow
# %tensorflow_version 1.x
import tensorflow as tf

# check the version
print(tf.__version__)

# needed for high-level file management
import shutil  

# logging for tensorflow
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)

# removes a saved model from the last training attempt.
shutil.rmtree('/tmp/DNN_house_regression_trained_model', ignore_errors=True)

estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.DNNRegressor(model_dir='/tmp/DNN_house_regression_trained_model', hidden_units=[20,18,14], optimizer=tf.train.AdamOptimizer(learning_rate=0.01), enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors.values)))

# Prints a log to show model is starting to train
print("starting to train");

# Train the model. Pass in predictor values and target values.
estimator.fit(predictors[:trainsize].values, targets[:trainsize].values.reshape(trainsize, noutputs)/SCALE_NUM_COLLISIONS, steps=10000)

# Next, we can check our predictions based on our predictors.
preds = estimator.predict(x=predictors[trainsize:].values)

# Apply the Scale value (not really needed here) to the outputs.
predslistscale = preds['scores']*SCALE_NUM_COLLISIONS

# pred = format(str(predslistscale)) # useful for checking outputs and printing.

# Calculate RMSE i.e. how good the model works using the predictions and targets.
# i.e. take the difference between the actual and the forecast then square the difference, 
# find the average of all the squares and then find the square root. 
# The RMSE essentially punishes larger errors i.e. it puts a heavier weight on larger errors.
rmse = np.sqrt(np.mean((targets[trainsize:].values - predslistscale)**2))
print('DNNRegression has RMSE of {0}'.format(rmse));


# Calculate the mean of the Number of Collisions Values.
avg = np.mean(shuffle['NUM_COLLISIONS'][:trainsize])

# Calculate the RMSE using the Number of Collisions Values and the mean of all target values.
# The fit of a proposed regression model should therefore be better than the fit of the mean model.
# In this case, it doesn't seem to be the case but it will vary on every run.
rmse = np.sqrt(np.mean((shuffle['NUM_COLLISIONS'][trainsize:] - avg)**2))
print('Just using average = {0} has RMSE of {1}'.format(avg, rmse));
# Out:
# 1.15.2
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa96ba99a90>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/DNN_house_regression_trained_model', '_session_creation_timeout_secs': 7200}
# starting to train
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/DNN_house_regression_trained_model/model.ckpt.
# INFO:tensorflow:loss = 422951.2, step = 1
# INFO:tensorflow:global_step/sec: 485.166
# INFO:tensorflow:loss = 7207.37, step = 101 (0.210 sec)
# INFO:tensorflow:global_step/sec: 636.15
# INFO:tensorflow:loss = 9232.117, step = 201 (0.157 sec)
# INFO:tensorflow:global_step/sec: 613.361
# INFO:tensorflow:loss = 7997.9194, step = 301 (0.164 sec)
# INFO:tensorflow:global_step/sec: 619.849
# INFO:tensorflow:loss = 6634.8154, step = 401 (0.161 sec)
# INFO:tensorflow:global_step/sec: 347.988
# INFO:tensorflow:loss = 6288.2505, step = 501 (0.285 sec)
# INFO:tensorflow:global_step/sec: 637.164
# INFO:tensorflow:loss = 8539.527, step = 601 (0.157 sec)
# INFO:tensorflow:global_step/sec: 664.832
# INFO:tensorflow:loss = 6940.6416, step = 701 (0.150 sec)
# INFO:tensorflow:global_step/sec: 645.152
# INFO:tensorflow:loss = 4920.6904, step = 801 (0.155 sec)
# INFO:tensorflow:global_step/sec: 652.509
# INFO:tensorflow:loss = 5326.262, step = 901 (0.154 sec)
# INFO:tensorflow:global_step/sec: 646.123
# INFO:tensorflow:loss = 5474.3164, step = 1001 (0.155 sec)
# INFO:tensorflow:global_step/sec: 645.507
# INFO:tensorflow:loss = 6531.213, step = 1101 (0.157 sec)
# INFO:tensorflow:global_step/sec: 584.602
# INFO:tensorflow:loss = 5262.6167, step = 1201 (0.171 sec)
# INFO:tensorflow:global_step/sec: 633.467
# INFO:tensorflow:loss = 4778.6875, step = 1301 (0.155 sec)
# INFO:tensorflow:global_step/sec: 670.855
# INFO:tensorflow:loss = 4984.4756, step = 1401 (0.149 sec)
# INFO:tensorflow:global_step/sec: 666.675
# INFO:tensorflow:loss = 8272.314, step = 1501 (0.150 sec)
# INFO:tensorflow:global_step/sec: 671.067
# INFO:tensorflow:loss = 5782.2363, step = 1601 (0.149 sec)
# INFO:tensorflow:global_step/sec: 660.148
# INFO:tensorflow:loss = 4702.34, step = 1701 (0.152 sec)
# INFO:tensorflow:global_step/sec: 625.856
# INFO:tensorflow:loss = 4663.6123, step = 1801 (0.160 sec)
# INFO:tensorflow:global_step/sec: 659.011
# INFO:tensorflow:loss = 4976.551, step = 1901 (0.152 sec)
# INFO:tensorflow:global_step/sec: 677.476
# INFO:tensorflow:loss = 4613.138, step = 2001 (0.148 sec)
# INFO:tensorflow:global_step/sec: 655.606
# INFO:tensorflow:loss = 5676.174, step = 2101 (0.153 sec)
# INFO:tensorflow:global_step/sec: 655.073
# INFO:tensorflow:loss = 5469.4854, step = 2201 (0.152 sec)
# INFO:tensorflow:global_step/sec: 630.783
# INFO:tensorflow:loss = 3844.4275, step = 2301 (0.159 sec)
# INFO:tensorflow:global_step/sec: 630.187
# INFO:tensorflow:loss = 5504.574, step = 2401 (0.159 sec)
# INFO:tensorflow:global_step/sec: 651.259
# INFO:tensorflow:loss = 5286.5537, step = 2501 (0.154 sec)
# INFO:tensorflow:global_step/sec: 655.9
# INFO:tensorflow:loss = 5256.1455, step = 2601 (0.152 sec)
# INFO:tensorflow:global_step/sec: 665.998
# INFO:tensorflow:loss = 6459.5957, step = 2701 (0.150 sec)
# INFO:tensorflow:global_step/sec: 657.587
# INFO:tensorflow:loss = 5611.176, step = 2801 (0.152 sec)
# INFO:tensorflow:global_step/sec: 640.05
# INFO:tensorflow:loss = 4748.4717, step = 2901 (0.157 sec)
# INFO:tensorflow:global_step/sec: 678.982
# INFO:tensorflow:loss = 6281.165, step = 3001 (0.147 sec)
# INFO:tensorflow:global_step/sec: 588.667
# INFO:tensorflow:loss = 4451.9414, step = 3101 (0.170 sec)
# INFO:tensorflow:global_step/sec: 660.842
# INFO:tensorflow:loss = 5132.0283, step = 3201 (0.151 sec)
# INFO:tensorflow:global_step/sec: 669.639
# INFO:tensorflow:loss = 4801.3022, step = 3301 (0.149 sec)
# INFO:tensorflow:global_step/sec: 620.939
# INFO:tensorflow:loss = 5386.4316, step = 3401 (0.162 sec)
# INFO:tensorflow:global_step/sec: 648.192
# INFO:tensorflow:loss = 5240.399, step = 3501 (0.154 sec)
# INFO:tensorflow:global_step/sec: 676.93
# INFO:tensorflow:loss = 4759.042, step = 3601 (0.148 sec)
# INFO:tensorflow:global_step/sec: 630.948
# INFO:tensorflow:loss = 4915.246, step = 3701 (0.158 sec)
# INFO:tensorflow:global_step/sec: 655.353
# INFO:tensorflow:loss = 5783.91, step = 3801 (0.153 sec)
# INFO:tensorflow:global_step/sec: 658.001
# INFO:tensorflow:loss = 4252.0933, step = 3901 (0.152 sec)
# INFO:tensorflow:global_step/sec: 643.428
# INFO:tensorflow:loss = 3933.774, step = 4001 (0.158 sec)
# INFO:tensorflow:global_step/sec: 664.278
# INFO:tensorflow:loss = 3418.9075, step = 4101 (0.148 sec)
# INFO:tensorflow:global_step/sec: 668.826
# INFO:tensorflow:loss = 5002.5264, step = 4201 (0.150 sec)
# INFO:tensorflow:global_step/sec: 628.209
# INFO:tensorflow:loss = 4567.701, step = 4301 (0.159 sec)
# INFO:tensorflow:global_step/sec: 626.81
# INFO:tensorflow:loss = 3993.7708, step = 4401 (0.160 sec)
# INFO:tensorflow:global_step/sec: 677.087
# INFO:tensorflow:loss = 3944.2092, step = 4501 (0.148 sec)
# INFO:tensorflow:global_step/sec: 672.385
# INFO:tensorflow:loss = 5417.4062, step = 4601 (0.149 sec)
# INFO:tensorflow:global_step/sec: 670.002
# INFO:tensorflow:loss = 3953.4026, step = 4701 (0.149 sec)
# INFO:tensorflow:global_step/sec: 655.738
# INFO:tensorflow:loss = 4702.6445, step = 4801 (0.152 sec)
# INFO:tensorflow:global_step/sec: 641.549
# INFO:tensorflow:loss = 5542.538, step = 4901 (0.156 sec)
# INFO:tensorflow:global_step/sec: 673.351
# INFO:tensorflow:loss = 4939.5464, step = 5001 (0.148 sec)
# INFO:tensorflow:global_step/sec: 639.683
# INFO:tensorflow:loss = 4184.0825, step = 5101 (0.156 sec)
# INFO:tensorflow:global_step/sec: 663.969
# INFO:tensorflow:loss = 4766.52, step = 5201 (0.151 sec)
# INFO:tensorflow:global_step/sec: 680.374
# INFO:tensorflow:loss = 5432.043, step = 5301 (0.147 sec)
# INFO:tensorflow:global_step/sec: 636.898
# INFO:tensorflow:loss = 5966.3623, step = 5401 (0.157 sec)
# INFO:tensorflow:global_step/sec: 672.41
# INFO:tensorflow:loss = 4345.3247, step = 5501 (0.149 sec)
# INFO:tensorflow:global_step/sec: 663.185
# INFO:tensorflow:loss = 4592.8926, step = 5601 (0.151 sec)
# INFO:tensorflow:global_step/sec: 594.274
# INFO:tensorflow:loss = 4717.547, step = 5701 (0.171 sec)
# INFO:tensorflow:global_step/sec: 636.156
# INFO:tensorflow:loss = 4292.659, step = 5801 (0.157 sec)
# INFO:tensorflow:global_step/sec: 669.619
# INFO:tensorflow:loss = 4618.882, step = 5901 (0.146 sec)
# INFO:tensorflow:global_step/sec: 664.178
# INFO:tensorflow:loss = 4162.0117, step = 6001 (0.150 sec)
# INFO:tensorflow:global_step/sec: 661.764
# INFO:tensorflow:loss = 5011.8594, step = 6101 (0.152 sec)
# INFO:tensorflow:global_step/sec: 646.496
# INFO:tensorflow:loss = 4561.001, step = 6201 (0.157 sec)
# INFO:tensorflow:global_step/sec: 636.938
# INFO:tensorflow:loss = 4179.241, step = 6301 (0.154 sec)
# INFO:tensorflow:global_step/sec: 607.038
# INFO:tensorflow:loss = 4878.4126, step = 6401 (0.166 sec)
# INFO:tensorflow:global_step/sec: 643.763
# INFO:tensorflow:loss = 3938.9019, step = 6501 (0.157 sec)
# INFO:tensorflow:global_step/sec: 638.163
# INFO:tensorflow:loss = 4105.5977, step = 6601 (0.154 sec)
# INFO:tensorflow:global_step/sec: 641.628
# INFO:tensorflow:loss = 4270.703, step = 6701 (0.155 sec)
# INFO:tensorflow:global_step/sec: 645.266
# INFO:tensorflow:loss = 3511.5984, step = 6801 (0.155 sec)
# INFO:tensorflow:global_step/sec: 629.641
# INFO:tensorflow:loss = 4322.1743, step = 6901 (0.159 sec)
# INFO:tensorflow:global_step/sec: 628.434
# INFO:tensorflow:loss = 4997.5117, step = 7001 (0.159 sec)
# INFO:tensorflow:global_step/sec: 650.317
# INFO:tensorflow:loss = 4617.3574, step = 7101 (0.155 sec)
# INFO:tensorflow:global_step/sec: 659.703
# INFO:tensorflow:loss = 4716.194, step = 7201 (0.151 sec)
# INFO:tensorflow:global_step/sec: 674.971
# INFO:tensorflow:loss = 4142.172, step = 7301 (0.148 sec)
# INFO:tensorflow:global_step/sec: 663.996
# INFO:tensorflow:loss = 5651.397, step = 7401 (0.151 sec)
# INFO:tensorflow:global_step/sec: 659.676
# INFO:tensorflow:loss = 4041.8867, step = 7501 (0.152 sec)
# INFO:tensorflow:global_step/sec: 652.977
# INFO:tensorflow:loss = 5374.6045, step = 7601 (0.153 sec)
# INFO:tensorflow:global_step/sec: 593.71
# INFO:tensorflow:loss = 4887.7656, step = 7701 (0.168 sec)
# INFO:tensorflow:global_step/sec: 642.39
# INFO:tensorflow:loss = 3940.6868, step = 7801 (0.156 sec)
# INFO:tensorflow:global_step/sec: 657.151
# INFO:tensorflow:loss = 4609.673, step = 7901 (0.152 sec)
# INFO:tensorflow:global_step/sec: 613.048
# INFO:tensorflow:loss = 4018.682, step = 8001 (0.163 sec)
# INFO:tensorflow:global_step/sec: 618.398
# INFO:tensorflow:loss = 4231.801, step = 8101 (0.164 sec)
# INFO:tensorflow:global_step/sec: 650.044
# INFO:tensorflow:loss = 4838.7646, step = 8201 (0.153 sec)
# INFO:tensorflow:global_step/sec: 635.606
# INFO:tensorflow:loss = 5288.5547, step = 8301 (0.156 sec)
# INFO:tensorflow:global_step/sec: 648.46
# INFO:tensorflow:loss = 5805.735, step = 8401 (0.154 sec)
# INFO:tensorflow:global_step/sec: 625.148
# INFO:tensorflow:loss = 4925.569, step = 8501 (0.160 sec)
# INFO:tensorflow:global_step/sec: 629.917
# INFO:tensorflow:loss = 4425.956, step = 8601 (0.159 sec)
# INFO:tensorflow:global_step/sec: 669.361
# INFO:tensorflow:loss = 3852.4854, step = 8701 (0.151 sec)
# INFO:tensorflow:global_step/sec: 639.256
# INFO:tensorflow:loss = 4678.4976, step = 8801 (0.155 sec)
# INFO:tensorflow:global_step/sec: 636.265
# INFO:tensorflow:loss = 5017.1104, step = 8901 (0.160 sec)
# INFO:tensorflow:global_step/sec: 610.272
# INFO:tensorflow:loss = 3822.6653, step = 9001 (0.162 sec)
# INFO:tensorflow:global_step/sec: 662.116
# INFO:tensorflow:loss = 3732.9128, step = 9101 (0.151 sec)
# INFO:tensorflow:global_step/sec: 653.448
# INFO:tensorflow:loss = 4118.973, step = 9201 (0.153 sec)
# INFO:tensorflow:global_step/sec: 671.594
# INFO:tensorflow:loss = 6477.1797, step = 9301 (0.148 sec)
# INFO:tensorflow:global_step/sec: 625.152
# INFO:tensorflow:loss = 5550.515, step = 9401 (0.160 sec)
# INFO:tensorflow:global_step/sec: 613.197
# INFO:tensorflow:loss = 4803.6523, step = 9501 (0.163 sec)
# INFO:tensorflow:global_step/sec: 624.206
# INFO:tensorflow:loss = 5172.9585, step = 9601 (0.161 sec)
# INFO:tensorflow:global_step/sec: 648.424
# INFO:tensorflow:loss = 5355.796, step = 9701 (0.156 sec)
# INFO:tensorflow:global_step/sec: 631.496
# INFO:tensorflow:loss = 4104.198, step = 9801 (0.156 sec)
# INFO:tensorflow:global_step/sec: 653.196
# INFO:tensorflow:loss = 3530.1375, step = 9901 (0.153 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/DNN_house_regression_trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 6562.747.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/DNN_house_regression_trained_model/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# DNNRegression has RMSE of 64.91302882407783
# Just using average = 598.0499742400824 has RMSE of 86.07378007407621

# %% [markdown]
# This model has been launched four times. The fourth time gave the smallest RDMS value (smallest errors).
#
# Each run gave the following values:
#
# * First attempt: `DNNRegression has RMSE of 65.24945640459521
# Just using average = 598.0499742400824 has RMSE of 86.07378007407621`
# * Second attempt: `DNNRegression has RMSE of 65.46612998488212
# Just using average = 598.0499742400824 has RMSE of 86.07378007407621`
# * Third attempt: `DNNRegression has RMSE of 65.07330068754943
# Just using average = 598.0499742400824 has RMSE of 86.07378007407621`
# * Fourth attempt: `DNNRegression has RMSE of 64.91302882407783
# Just using average = 598.0499742400824 has RMSE of 86.07378007407621`

# %% [markdown]
# ### **Testing the DNN regression model**

# %% [markdown]
# #### **Checking seasonality**

# %% [markdown]
# In the first part of the report, a seasonality was noted for the number of collisions throughout the year: from January to the end of May (~ 150 days) it increases, then from mid-year to mid-August (~ 225-234 days of the year) it decreases, to increase until mid-December (~ 350 day of the year). At the end of the year, a significant drop in the number of collisions is visible (~ 360-365 days of the year).
#
# Tests will be carried out below to check whether the number of traffic collisions predicted by the DNN regression model confirms this observation.
#
# In order to help in the selection of values for individual weather factors in a given part of the year so that they do not differ significantly from the conditions prevailing in that period, the real data is presented below.

# %%
# print out the shuffled data (first 60 rows) - help for input values for tests
shuffle[:60]
# Out:
#       Apr  Aug  Dec  Feb  Jan  ...   max   min  prcp  fog  NUM_COLLISIONS
# 1325    0    0    0    0    0  ...  57.0  51.8  3.76    0             539
# 1084    0    0    0    1    0  ...  54.0  32.0  1.44    1             607
# 303     0    0    0    0    0  ...  64.0  37.0  0.01    0             646
# 1724    0    0    1    0    0  ...  57.0  28.0  0.47    0             651
# 532     0    0    0    0    0  ...  73.9  63.0  0.04    0             614
# 1527    0    0    0    0    0  ...  55.0  39.9  0.00    0             651
# 846     0    0    0    0    0  ...  61.0  51.1  0.08    0             642
# 1877    0    0    0    0    0  ...  57.0  48.0  0.00    1             689
# 624     0    0    0    0    0  ...  70.0  60.1  0.07    1             639
# 1266    0    1    0    0    0  ...  80.1  64.0  0.00    0             618
# 2222    0    0    0    0    0  ...  64.9  45.0  0.01    0             637
# 853     0    0    0    0    0  ...  70.0  53.1  0.00    0             652
# 735     0    0    0    1    0  ...  33.1  10.9  0.00    0             449
# 2189    1    0    0    0    0  ...  60.1  36.0  0.07    0             587
# 9       0    0    0    0    1  ...  46.4  39.2  0.17    0             475
# 2177    0    0    0    0    0  ...  48.0  32.0  0.00    0             526
# 125     0    0    0    0    0  ...  57.0  46.0  0.07    0             577
# 2056    0    0    0    0    0  ...  54.0  37.9  0.00    0             697
# 993     0    0    0    0    0  ...  66.0  46.9  0.54    1             767
# 1149    1    0    0    0    0  ...  57.9  37.9  0.13    0             700
# 804     1    0    0    0    0  ...  52.0  39.9  0.00    0             630
# 1086    0    0    0    1    0  ...  44.1  28.0  0.00    0             423
# 2000    0    0    0    0    0  ...  69.1  53.1  0.00    0             715
# 1756    0    0    0    0    1  ...  42.1  21.9  0.00    0             687
# 2190    1    0    0    0    0  ...  60.1  37.9  0.01    0             487
# 13      0    0    0    0    1  ...  41.0  37.0  0.47    1             491
# 2318    0    1    0    0    0  ...  77.0  62.1  0.00    1             533
# 1512    1    0    0    0    0  ...  55.9  43.0  0.27    0             517
# 1862    1    0    0    0    0  ...  60.1  39.9  0.13    1             604
# 736     0    0    0    1    0  ...  37.9  30.9  0.04    0             547
# 1492    1    0    0    0    0  ...  54.0  32.0  0.00    0             646
# 2390    0    0    0    0    0  ...  60.1  52.0  0.00    0             639
# 370     0    0    0    0    1  ...  36.0  18.0  0.01    1             498
# 2090    0    0    1    0    0  ...  39.9  27.0  0.00    0             514
# 2325    0    1    0    0    0  ...  75.9  63.0  0.00    0             514
# 247     0    0    0    0    0  ...  75.0  66.9  0.00    0             695
# 665     0    0    0    0    0  ...  63.0  34.0  2.91    0             712
# 1910    0    0    0    0    0  ...  78.1  52.0  0.00    1             698
# 782     0    0    0    0    0  ...  39.9  28.9  0.19    0             505
# 2105    0    0    0    0    1  ...  37.0  26.1  0.00    0             644
# 56      0    0    0    0    0  ...  43.0  32.0  0.00    0             597
# 813     1    0    0    0    0  ...  55.9  39.9  0.00    0             679
# 902     0    0    0    0    0  ...  86.0  69.1  0.00    0             717
# 2030    0    0    0    0    0  ...  52.0  36.0  0.36    0             650
# 691     0    0    1    0    0  ...  52.0  41.0  0.10    1             555
# 80      0    0    0    0    0  ...  54.0  39.0  0.02    0             520
# 8       0    0    0    0    1  ...  44.1  32.0  0.00    0             660
# 1909    0    0    0    0    0  ...  82.0  54.0  0.00    0             627
# 2317    0    1    0    0    0  ...  73.9  62.1  0.00    1             523
# 1914    0    0    0    0    0  ...  70.0  57.9  0.25    1             733
# 2101    0    0    0    0    1  ...  45.0  21.9  0.00    0             583
# 961     0    0    0    0    0  ...  70.0  48.0  0.00    0             493
# 1393    0    0    1    0    0  ...  41.0  30.0  0.00    0             719
# 1260    0    1    0    0    0  ...  73.9  55.9  0.00    0             715
# 504     0    0    0    0    0  ...  77.0  55.9  0.00    0             516
# 1119    0    0    0    0    0  ...  46.0  41.0  0.00    0             640
# 2187    1    0    0    0    0  ...  50.0  37.0  0.19    0             660
# 1367    0    0    0    0    0  ...  48.9  30.0  0.00    0             428
# 1992    0    0    0    0    0  ...  79.0  63.0  0.00    1             718
# 39      0    0    0    1    0  ...  43.0  28.0  0.11    0             631
#
# [60 rows x 31 columns]

# %%
#"Apr", "Aug", "Dec", "Feb", "Jan", "Jul", "Jun", "Mar", "May", "Nov", "Oct", "Sep", "Fri", "Mon", "Sat", "Sun", "Thu", "Tue", "Wed", "year", "temp", "dewp", "slp", "visib", "wdsp", "mxpsd", "max", "min", "prcp", "fog"
input = pd.DataFrame.from_dict(data = 
				{
         'Apr' : [0,0,0],
         'Aug' : [0,0,0],
         'Dec' : [1,1,1],
         'Feb' : [0,0,0],
         'Jan' : [0,0,0],
         'Jul' : [0,0,0],
         'Jun' : [0,0,0],
         'Mar' : [0,0,0],
         'May' : [0,0,0],
         'Nov' : [0,0,0],
         'Oct' : [0,0,0],
         'Sep' : [0,0,0],
         'Fri' : [0,0,0],
         'Mon' : [0,1,0],
         'Sat' : [0,0,0],
         'Sun' : [1,0,0],
         'Thu' : [0,0,0],
         'Tue' : [0,0,0],
         'Wed' : [0,0,1],
         'year' : [2019, 2015, 2013],
         'temp' : [44, 45.1, 37.6],
         'dewp' : [18.8, 34.3, 45.2],
         'slp' : [1026.6, 1011.5, 1018.3],
         'visib' : [8, 9, 10],
         'wdsp' : [9.2, 10.2, 13.7],
         'mxpsd' : [18, 24.2, 16.9],
         'max' : [40.1, 48.2, 54.9],
         'min' : [29.8, 35.2, 32.9],
         'prcp' : [0, 0.22, 0.39],
         'fog' : [0, 1, 0]
        })

estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.DNNRegressor(model_dir='/tmp/DNN_house_regression_trained_model', hidden_units=[20,18,14], enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(input.values)))

preds = estimator.predict(x=input.values)

predslistnorm = preds['scores']
prednorm = format(str(predslistnorm))
print(prednorm)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa96bda2190>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/DNN_house_regression_trained_model', '_session_creation_timeout_secs': 7200}
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/DNN_house_regression_trained_model/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [492.23422 609.13715 620.2196 ]

# %% [markdown]
# The test was performed twelve times in total, three times for the following months:
#
# * January
# * May
# * August
# * December
#
# Different values for weather factors, days and years were used. The obtained results are presented below:

# %% [markdown]
# > **For January**:
#
# *1st attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [1,1,1],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,1],
#          'Mon' : [1,0,0],
#          'Sat' : [0,0,0],
#          'Sun' : [0,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,1,0],
#          'year' : [2013, 2014, 2015],
#          'temp' : [42.7, 31.4, 39.4],
#          'dewp' : [41.5, 24.2, 34.6],
#          'slp' : [1022.6, 1029.7, 1014.2],
#          'visib' : [7.1, 10.0, 8.6],
#          'wdsp' : [7.9, 6.6, 8.6],
#          'mxpsd' : [13.0, 14.0, 14.0],
#          'max' : [46.4, 42.1, 41.0],
#          'min' : [39.2, 21.9, 37.0],
#          'prcp' : [0.17, 0.00, 0.47],
#          'fog' : [0, 0, 1]
#          `
#
#
# *1st attempt - Outputs:*
# * `553.6691`
# * `562.4535`
# * `606.4983`
#
#
# *2nd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [1,1,1],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,0,0],
#          'Sat' : [0,0,1],
#          'Sun' : [0,0,0],
#          'Thu' : [0,1,0],
#          'Tue' : [1,0,0],
#          'Wed' : [0,0,0],
#          'year' : [2016, 2017, 2018],
#          'temp' : [33.8, 35.0, 32.1],
#          'dewp' : [21.0, 34.2, 27.5],
#          'slp' : [1019.2, 1011.0, 1016.5],
#          'visib' : [8.3, 7.9, 10.1],
#          'wdsp' : [6.8, 9.2, 7.7],
#          'mxpsd' : [14.0, 13.0, 13.5],
#          'max' : [40.9, 44.5, 42.0],
#          'min' : [22.7, 35.4, 25.9],
#          'prcp' : [0.00, 0.38, 0.22],
#          'fog' : [1, 0, 1]
#          `
#
# *2nd attempt - Outputs:*
# * `572.71326`
# * `580.30835`
# * `510.4562`
#
#
# *3rd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [1,1,1],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,1,0],
#          'Sat' : [0,0,0],
#          'Sun' : [1,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,0,1],
#          'year' : [2019, 2015, 2013],
#          'temp' : [36.6, 31.2, 38.7],
#          'dewp' : [29.5, 28.6, 26.0],
#          'slp' : [1012.3, 1019.1, 1015.4],
#          'visib' : [9.4, 8.1, 9.5],
#          'wdsp' : [7.0, 7.6, 8.2],
#          'mxpsd' : [12.9, 14.1, 13.9],
#          'max' : [41.2, 40.8, 41.3],
#          'min' : [32.3, 26.4, 29.8],
#          'prcp' : [0.11, 0.08, 0.19],
#          'fog' : [0, 1, 0]
#          `
#
# *3rd attempt - Outputs:*
# * `450.92697`
# * `551.10675`
# * `568.18286`

# %% [markdown]
# > **For May**:
#
# *1st attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [1,1,1],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,1],
#          'Mon' : [1,0,0],
#          'Sat' : [0,0,0],
#          'Sun' : [0,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,1,0],
#          'year' : [2013, 2014, 2015],
#          'temp' : [48.3, 50.5, 56.8],
#          'dewp' : [34.9, 49.6, 49.5],
#          'slp' : [1014.8, 1016.9, 1014.3],
#          'visib' : [10, 6.4, 7],
#          'wdsp' : [6.2, 5.5, 10],
#          'mxpsd' : [8.9, 9.9, 15],
#          'max' : [55, 57, 64.9],
#          'min' : [39.9, 48, 45],
#          'prcp' : [0, 0, 0.01],
#          'fog' : [0, 1, 0]
#          `
#
#
# *1st attempt - Outputs:*
# * `615.00916`
# * `632.8248`
# * `684.0004`
#
#
# *2nd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [1,1,1],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,0,0],
#          'Sat' : [0,0,1],
#          'Sun' : [0,0,0],
#          'Thu' : [0,1,0],
#          'Tue' : [1,0,0],
#          'Wed' : [0,0,0],
#          'year' : [2016, 2017, 2018],
#          'temp' : [51.1, 54.0, 53.3],
#          'dewp' : [45.2, 41.3, 47.2],
#          'slp' : [1015.0, 1014.9, 1016.1],
#          'visib' : [8.6, 7.8, 9.2],
#          'wdsp' : [5.8, 7.9, 6.6],
#          'mxpsd' : [12, 10.2, 13.2],
#          'max' : [61.8, 58.2, 60.1],
#          'min' : [41.3, 47.2, 46.3],
#          'prcp' : [0.01, 0.01, 0],
#          'fog' : [1, 0, 0]
#          `
#
# *2nd attempt - Outputs:*
# * `642.1402`
# * `652.09546`
# * `577.7129`
#
#
# *3rd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [1,1,1],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,1,0],
#          'Sat' : [0,0,0],
#          'Sun' : [1,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,0,1],
#          'year' : [2019, 2015, 2013],
#          'temp' : [49.7, 52.2, 54.8],
#          'dewp' : [35.8, 48.9, 45.4],
#          'slp' : [1016.1, 1015.5, 1014.7],
#          'visib' : [6.9, 8.2, 7.3],
#          'wdsp' : [9.8, 6.8, 7.4],
#          'mxpsd' : [9.2, 12.4, 11.6],
#          'max' : [57.2, 62.1, 59.9],
#          'min' : [40.1, 45.8, 42.6],
#          'prcp' : [0, 0.01, 0],
#          'fog' : [0, 1, 0]
#          `
#
# *3rd attempt - Outputs:*
# * `515.43024`
# * `624.81854`
# * `639.746 `

# %% [markdown]
# > **For August**:
#
# *1st attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [1,1,1],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,1],
#          'Mon' : [1,0,0],
#          'Sat' : [0,0,0],
#          'Sun' : [0,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,1,0],
#          'year' : [2013, 2014, 2015],
#          'temp' : [70.6, 67.5, 68.3],
#          'dewp' : [67.2, 65.3, 58.5],
#          'slp' : [1023.2, 1017.6, 1018.7],
#          'visib' : [9.9, 3.8, 10],
#          'wdsp' : [8.6, 7.1, 12.3],
#          'mxpsd' : [14, 11.1, 17.1],
#          'max' : [80.1, 77, 75.9],
#          'min' : [64, 62.1, 63],
#          'prcp' : [0, 0, 0],
#          'fog' : [0, 1, 0]
#          `
#
#
# *1st attempt - Outputs:*
# * `592.21747`
# * `608.9144`
# * `646.9852`
#
#
# *2nd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [1,1,1],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,0,0],
#          'Sat' : [0,0,1],
#          'Sun' : [0,0,0],
#          'Thu' : [0,1,0],
#          'Tue' : [1,0,0],
#          'Wed' : [0,0,0],
#          'year' : [2016, 2017, 2018],
#          'temp' : [68.3, 69.8, 70.1],
#          'dewp' : [61.1, 64.8, 62.7],
#          'slp' : [1020.4, 1020.1, 1019.9],
#          'visib' : [6, 9, 5.5],
#          'wdsp' : [10.8, 8.4, 11.2],
#          'mxpsd' : [12, 16, 13.5],
#          'max' : [78.3, 77.8, 76.5],
#          'min' : [62.5, 63.9, 63],
#          'prcp' : [0, 0, 0],
#          'fog' : [0, 0, 1]
#          `
#
# *2nd attempt - Outputs:*
# * `613.399`
# * `621.2207`
# * `559.2971`
#
#
# *3rd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [1,1,1],
#          'Dec' : [0,0,0],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,1,0],
#          'Sat' : [0,0,0],
#          'Sun' : [1,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,0,1],
#          'year' : [2019, 2015, 2013],
#          'temp' : [69.2, 68.4, 69.9],
#          'dewp' : [59.1, 67, 61.5],
#          'slp' : [1022, 1021, 1018.9],
#          'visib' : [9.5, 5.2, 8.1],
#          'wdsp' : [7.9, 9, 11.5],
#          'mxpsd' : [13, 15, 16.6],
#          'max' : [79.6, 76.4, 78],
#          'min' : [63.1, 62.9, 64],
#          'prcp' : [0, 0, 0],
#          'fog' : [1, 0, 0]
#          `
#
# *3rd attempt - Outputs:*
# * `499.8673`
# * `591.60535`
# * `611.2499`

# %% [markdown]
# > **For December**:
#
# *1st attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [1,1,1],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,1],
#          'Mon' : [1,0,0],
#          'Sat' : [0,0,0],
#          'Sun' : [0,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,1,0],
#          'year' : [2013, 2014, 2015],
#          'temp' : [51.3, 31.8, 48.6],
#          'dewp' : [48.7, 12.5, 45.7],
#          'slp' : [1012.7, 1027.5, 1009.7],
#          'visib' : [7.9, 10, 8],
#          'wdsp' : [15, 11.1, 8.8],
#          'mxpsd' : [26, 15.9, 15],
#          'max' : [57, 39.9, 52],
#          'min' : [28, 27, 41],
#          'prcp' : [0.47, 0, 0.1],
#          'fog' : [0, 0, 1]
#          `
#
#
# *1st attempt - Outputs:*
# * `624.53766`
# * `608.4956`
# * `661.6003`
#
#
# *2nd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [1,1,1],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,0,0],
#          'Sat' : [0,0,1],
#          'Sun' : [0,0,0],
#          'Thu' : [0,1,0],
#          'Tue' : [1,0,0],
#          'Wed' : [0,0,0],
#          'year' : [2016, 2017, 2018],
#          'temp' : [42.6, 38.2, 45.3],
#          'dewp' : [44.4, 28.6, 30.4],
#          'slp' : [1015.3, 1022.9, 1021.1],
#          'visib' : [9, 8, 9],
#          'wdsp' : [12, 13, 10.4],
#          'mxpsd' : [17.2, 19.9, 16.4],
#          'max' : [44.2, 46.8, 50.1],
#          'min' : [32.8, 38.7, 40],
#          'prcp' : [0.21, 0.2, 0.32],
#          'fog' : [1, 0, 0]
#          `
#
# *2nd attempt - Outputs:*
# * `624.9684`
# * `629.9253`
# * `561.87256`
#
#
# *3rd attempt - Inputs:*
#
# `'Apr' : [0,0,0],
#          'Aug' : [0,0,0],
#          'Dec' : [1,1,1],
#          'Feb' : [0,0,0],
#          'Jan' : [0,0,0],
#          'Jul' : [0,0,0],
#          'Jun' : [0,0,0],
#          'Mar' : [0,0,0],
#          'May' : [0,0,0],
#          'Nov' : [0,0,0],
#          'Oct' : [0,0,0],
#          'Sep' : [0,0,0],
#          'Fri' : [0,0,0],
#          'Mon' : [0,1,0],
#          'Sat' : [0,0,0],
#          'Sun' : [1,0,0],
#          'Thu' : [0,0,0],
#          'Tue' : [0,0,0],
#          'Wed' : [0,0,1],
#          'year' : [2019, 2015, 2013],
#          'temp' : [44, 45.1, 37.6],
#          'dewp' : [18.8, 34.3, 45.2],
#          'slp' : [1026.6, 1011.5, 1018.3],
#          'visib' : [8, 9, 10],
#          'wdsp' : [9.2, 10.2, 13.7],
#          'mxpsd' : [18, 24.2, 16.9],
#          'max' : [40.1, 48.2, 54.9],
#          'min' : [29.8, 35.2, 32.9],
#          'prcp' : [0, 0.22, 0.39],
#          'fog' : [0, 1, 0]
#          `
#
# *3rd attempt - Outputs:*
# * `492.23422`
# * `609.13715`
# * `620.2196`

# %% [markdown]
# The average of results given from DNN Regression Model for January is 550.7017, 620.4197 for May, 593.8618 for August and 603.6656 for December.
# In other words, the predicted number of vehicle collisions (the average of the results) is as follows:
#
# * 551 for January
# * 620 for May
# * 594 for August
# * 604 for December
#
# This confirms the seasonality noted in the first part of the report - the number of collisions increases from January to May, then declines until August and then increases again until December.

# %% [markdown]
# # **CONCLUSIONS**

# %% [markdown]
# Predicted number of collisions by the **Linear Regression Model**:
#
# * confirms that the number of collisions increases from Monday to Friday,
# * confirms that the number of collisions increases when the temperature increases,
# * denies an increase in the number of collisions with an increase in the value of dew point. When the value of the dew point increases, the predicted number of collisions decreases.
#
# Predicted number of collisions by the **Deep Neural Network Regression Model** confirms the seasonality. The number of predicted collisions increases from January to May, then decreases until August and then increases again until December.

# %% [markdown]
# # **REFERENCES**

# %% [markdown]
# Python Software Foundation. Python Language Reference, [https://www.python.org](https://www.python.org)

# %% [markdown]
# R Core Team. 2020. R: A Language and Environment for Statistical Computing. Vienna, Austria: R Foundation for Statistical Computing. [https://www.R-project.org/](https://www.R-project.org/).

# %% [markdown]
# reback2020pandas, The pandas development team,
# pandas-dev/pandas: Pandas, feb 2020, Zenodo, https://doi.org/10.5281/zenodo.3509134

# %% [markdown]
# [Data structures for statistical computing in python](https://conference.scipy.org/proceedings/scipy2010/pdfs/mckinney.pdf), McKinney, Proceedings of the 9th Python in Science Conference, Volume 445, 2010.

# %% [markdown]
# [NumPy — NumPy](https://numpy.org/). numpy.org. NumPy developers.

# %% [markdown]
# McKinney, Wes (2017). Python for Data Analysis : Data Wrangling with Pandas, NumPy, and IPython (2nd ed.). Sebastopol: O'Reilly. ISBN 978-1-4919-5766-0.

# %% [markdown]
# VanderPlas, Jake (2016). "Introduction to NumPy". Python Data Science Handbook: Essential Tools for Working with Data. O'Reilly. pp. 33–96. ISBN 978-1-4919-1205-8.

# %% [markdown]
# [Adam: A Method for Stochastic Optimization](https://arxiv.org/abs/1412.6980), 2015.

# %% [markdown]
# Martín Abadi, Ashish Agarwal, Paul Barham, Eugene Brevdo,
# Zhifeng Chen, Craig Citro, Greg S. Corrado, Andy Davis,
# Jeffrey Dean, Matthieu Devin, Sanjay Ghemawat, Ian Goodfellow,
# Andrew Harp, Geoffrey Irving, Michael Isard, Rafal Jozefowicz, Yangqing Jia,
# Lukasz Kaiser, Manjunath Kudlur, Josh Levenberg, Dan Mané, Mike Schuster,
# Rajat Monga, Sherry Moore, Derek Murray, Chris Olah, Jonathon Shlens,
# Benoit Steiner, Ilya Sutskever, Kunal Talwar, Paul Tucker,
# Vincent Vanhoucke, Vijay Vasudevan, Fernanda Viégas,
# Oriol Vinyals, Pete Warden, Martin Wattenberg, Martin Wicke,
# Yuan Yu, and Xiaoqiang Zheng.
# TensorFlow: Large-scale machine learning on heterogeneous systems,
# 2015. Software available from [tensorflow.org](https://www.tensorflow.org/).

# %% [markdown]
# shutil — High-level file operations,  [https://docs.python.org/3/library/shutil.html](https://docs.python.org/3/library/shutil.html), Source code: [Lib/shutil.py](https://github.com/python/cpython/blob/3.9/Lib/shutil.py)

# %% [markdown]
# Chai, Tianfeng & Draxler, R.. (2014). Root mean square error (RMSE) or mean absolute error (MAE)?. Geosci. Model Dev.. 7. 10.5194/gmdd-7-1525-2014.
